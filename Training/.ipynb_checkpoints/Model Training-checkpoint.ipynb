# %% [markdown]
# # Image Preprocessing

# %%
# Importing Libraries
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading Model

vgg = VGG16(input_shape=[64,64] + [3], weights = 'imagenet', include_top = False)

# %%
# don't train existing weights

for layer in vgg.layers:
    layer.trainable = False
    
# our layers
x = Flatten()(vgg.output)

# %%
# Adding Output layer

prediction = Dense(17, activation = 'softmax')(x)

# %%
# creating a model object

model = Model(inputs = vgg.input, outputs = prediction)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 64, 64, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 8, 8, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 17)             │        34,833 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,749,521 (56.26 MB)
#  Trainable params: 34,833 (136.07 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
# Compile the model

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'], run_eagerly = True)

# %%
# importing datagen library

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Loading train and test set

X_train = train_datagen.flow_from_directory(r"C:\Users\HP\Desktop\SI-GuidedProject-322160-1664774275-main\Dataset\train", target_size = (64, 64), batch_size = 32, class_mode = 'categorical')
X_test = test_datagen.flow_from_directory(r"C:\Users\HP\Desktop\SI-GuidedProject-322160-1664774275-main\Dataset\test", target_size = (64, 64), batch_size = 32, class_mode = 'categorical')
# Out:
# Found 655 images belonging to 17 classes.
# Found 183 images belonging to 17 classes.

# %%
# checking indices

X_train.class_indices
# Out:
# {'Darier_s disease': 0,
#  'Muehrck-e_s lines': 1,
#  'aloperia areata': 2,
#  'beau_s lines': 3,
#  'bluish nail': 4,
#  'clubbing': 5,
#  'eczema': 6,
#  'half and half nailes (Lindsay_s nails)': 7,
#  'koilonychia': 8,
#  'leukonychia': 9,
#  'onycholycis': 10,
#  'pale nail': 11,
#  'red lunula': 12,
#  'splinter hemmorrage': 13,
#  'terry_s nail': 14,
#  'white nail': 15,
#  'yellow nails': 16}

# %%
import sys
# fit the model
r = model.fit(
    X_train,
    validation_data=X_test,
    epochs=10,
    steps_per_epoch=len( X_train)//3,
    validation_steps=len( X_test)//3
)
# Out:
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.1014 - loss: 2.9283 - val_accuracy: 0.0625 - val_loss: 2.9564
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 0.0938 - loss: 2.8285 - val_accuracy: 0.1094 - val_loss: 2.8548
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 0.1384 - loss: 2.7268 - val_accuracy: 0.0938 - val_loss: 2.6572
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.1830 - loss: 2.6442 - val_accuracy: 0.1562 - val_loss: 2.7134
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.1786 - loss: 2.5874 - val_accuracy: 0.2344 - val_loss: 2.4776
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.2657 - loss: 2.4985 - val_accuracy: 0.2500 - val_loss: 2.4616
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.2705 - loss: 2.4105 - val_accuracy: 0.2344 - val_loss: 2.4837
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.3304 - loss: 2.3560 - val_accuracy: 0.2969 - val_loss: 2.4260
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.2946 - loss: 2.3196 - val_accuracy: 0.2812 - val_loss: 2.4421
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.3036 - loss: 2.2926 - val_accuracy: 0.2812 - val_loss: 2.3765

# %%
model.save('Vgg-16-nail-disease.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
import numpy as np

# %%
model=load_model('vgg-16-nail-disease.h5')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15488\287964318.py in ?()
# ----> 1 model=load_model('vgg-16-nail-disease.h5')
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\saving\saving_api.py in ?(filepath, custom_objects, compile, safe_mode)
#     192             compile=compile,
#     193             safe_mode=safe_mode,
#     194         )
#     195     if str(filepath).endswith((".h5", ".hdf5")):
# --> 196         return legacy_h5_format.load_model_from_hdf5(
#     197             filepath,
#     198             custom_objects=custom_objects,
#     199             compile=compile,
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\legacy\saving\legacy_h5_format.py in ?(filepath, custom_objects, compile, safe_mode)
#     194                         "optimizer."
#     195                     )
#     196     finally:
#     197         if opened_new_file:
# --> 198             f.close()
#     199     return model
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\legacy\saving\saving_utils.py in ?(config, custom_objects)
#      79             function_dict["config"]["defaults"] = function_config[1]
#      80             function_dict["config"]["closure"] = function_config[2]
#      81             config["config"]["function"] = function_dict
#      82
# ---> 83     return serialization.deserialize_keras_object(
#      84         config,
#      85         module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86         custom_objects=custom_objects,
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\legacy\saving\serialization.py in ?(identifier, module_objects, custom_objects, printable_module_name)
#     484             arg_spec = inspect.getfullargspec(cls.from_config)
#     485             custom_objects = custom_objects or {}
#     486
#     487             if "custom_objects" in arg_spec.args:
# --> 488                 deserialized_obj = cls.from_config(
#     489                     cls_config,
#     490                     custom_objects={
#     491                         **object_registration.GLOBAL_CUSTOM_OBJECTS,
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\models\model.py in ?(cls, config, custom_objects)
#     819             # Revive Functional model
#     820             # (but not Functional subclasses with a custom __init__)
#     821             from keras.src.models.functional import functional_from_config
#     822
# --> 823             return functional_from_config(
#     824                 cls, config, custom_objects=custom_objects
#     825             )
#     826
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\models\functional.py in ?(cls, config, custom_objects)
#     580                         process_node(layer, node_data)
#     581
#     582                     # If the node does not have all inbound layers
#     583                     # available, stop processing and continue later
# --> 584                     except IndexError:
#     585                         break
#     586
#     587                     node_index += 1
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\models\functional.py in ?(layer, node_data)
#     506         """
#     507         args, kwargs = deserialize_node(node_data, created_layers)
#     508         # Call layer on its inputs, thus creating the node
#     509         # and building the layer if needed.
# --> 510         layer(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     874
#     875         ################
#     876         # 4. Call build
#     877         with self._open_name_scope():
# --> 878             self._maybe_build(call_spec)
#     879
#     880         ##########################
#     881         # 5. Infer training value
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\layer.py in ?(self, call_spec)
#    1485                 shapes_dict=shapes_dict,
#    1486                 call_spec=call_spec,
#    1487                 class_name=self.__class__.__name__,
#    1488             )
# -> 1489             self.build(**shapes_dict)
#    1490             # Check input spec again (after build, since self.input_spec
#    1491             # may have been updated
#    1492             self._assert_input_compatibility(call_spec.first_arg)
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\layer.py in ?(*args, **kwargs)
#     228         @wraps(original_build_method)
#     229         def build_wrapper(*args, **kwargs):
#     230             with obj._open_name_scope():
#     231                 obj._path = current_path()
# --> 232                 original_build_method(*args, **kwargs)
#     233             # Record build config.
#     234             signature = inspect.signature(original_build_method)
#     235             obj._build_shapes_dict = signature.bind(*args, **kwargs).arguments
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py in ?(self, input_shape)
#     198         # compute_output_shape contains some validation logic for the input
#     199         # shape, and make sure the output shape has all positive dimensions.
#     200         self.compute_output_shape(input_shape)
#     201
# --> 202         self._kernel = self.add_weight(
#     203             name="kernel",
#     204             shape=kernel_shape,
#     205             initializer=self.kernel_initializer,
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\layer.py in ?(self, shape, initializer, dtype, trainable, autocast, regularizer, constraint, aggregation, overwrite_with_gradient, name)
#     574             else:
#     575                 initializer = "zeros"
#     576         initializer = initializers.get(initializer)
#     577         with backend.name_scope(self.name, caller=self):
# --> 578             variable = backend.Variable(
#     579                 initializer=initializer,
#     580                 shape=shape,
#     581                 dtype=dtype,
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\common\variables.py in ?(***failed resolving arguments***)
#     202                 )
#     203         else:
#     204             if callable(initializer):
#     205                 self._shape = self._validate_shape(shape)
# --> 206                 self._initialize_with_initializer(initializer)
#     207             else:
#     208                 self._initialize(initializer)
#     209                 self._shape = self._validate_shape(self._value.shape)
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\core.py in ?(self, initializer)
#      51     def _initialize_with_initializer(self, initializer):
# ---> 52         self._initialize(lambda: initializer(self._shape, dtype=self._dtype))
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\core.py in ?(self, value)
#      38     def _initialize(self, value):
#      39         if isinstance(value, tf.Variable):
#      40             self._value = value
#      41         else:
# ---> 42             self._value = tf.Variable(
#      43                 value,
#      44                 dtype=self._dtype,
#      45                 trainable=self.trainable,
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\variables.py in ?(cls, *args, **kwargs)
#     195   @traceback_utils.filter_traceback
#     196   def __call__(cls, *args, **kwargs):
#     197     if hasattr(cls, "_variable_call") and callable(cls._variable_call):
# --> 198       variable_call = cls._variable_call(*args, **kwargs)
#     199       if variable_call is not None:
#     200         return variable_call
#     201     return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\variables.py in ?(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape, experimental_enable_variable_lifting, **kwargs)
#    1226
#    1227     # Reset `aggregation` that is explicitly set as `None` to the enum NONE.
#    1228     if aggregation is None:
#    1229       aggregation = VariableAggregation.NONE
# -> 1230     return previous_getter(
#    1231         initial_value=initial_value,
#    1232         trainable=trainable,
#    1233         validate_shape=validate_shape,
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\variables.py in ?(**kws)
# -> 1223     previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\variables.py in ?(next_creator, **kwds)
#      48 def default_variable_creator_v2(next_creator=None, **kwds):
#      49   from tensorflow.python.ops import resource_variable_ops  # pylint: disable=g-import-not-at-top
#      50
# ---> 51   return resource_variable_ops.default_variable_creator_v2(
#      52       next_creator=next_creator, **kwds)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\resource_variable_ops.py in ?(next_creator, **kwargs)
#     355   shape = kwargs.get("shape", None)
#     356   experimental_enable_variable_lifting = kwargs.get(
#     357       "experimental_enable_variable_lifting", None)
#     358
# --> 359   return ResourceVariable(
#     360       initial_value=initial_value,
#     361       trainable=trainable,
#     362       validate_shape=validate_shape,
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\variables.py in ?(cls, *args, **kwargs)
#     197     if hasattr(cls, "_variable_call") and callable(cls._variable_call):
#     198       variable_call = cls._variable_call(*args, **kwargs)
#     199       if variable_call is not None:
#     200         return variable_call
# --> 201     return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\resource_variable_ops.py in ?(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape, handle, experimental_enable_variable_lifting)
#    1872                              shape=shape,
#    1873                              dtype=dtype,
#    1874                              handle=handle)
#    1875     else:
# -> 1876       self._init_from_args(
#    1877           initial_value=initial_value,
#    1878           trainable=trainable,
#    1879           collections=collections,
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\resource_variable_ops.py in ?(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape, validate_shape, experimental_enable_variable_lifting)
#    2056                 s=[compat.as_bytes("loc:@%s" % handle_name)]))
#    2057         with ops.get_default_graph()._attr_scope({"_class": attr}):
#    2058           with ops.name_scope("Initializer"), device_context_manager(None):
#    2059             if init_from_fn:
# -> 2060               initial_value = initial_value()
#    2061             if isinstance(initial_value, trackable.CheckpointInitialValue):
#    2062               self._maybe_initialize_trackable()
#    2063               self._update_uid = initial_value.checkpoint_position.restore_uid
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\core.py in ?()
# ---> 52         self._initialize(lambda: initializer(self._shape, dtype=self._dtype))
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\initializers\random_initializers.py in ?(self, shape, dtype)
#     302                 shape, mean=0.0, stddev=stddev, dtype=dtype, seed=self.seed
#     303             )
#     304         else:
#     305             limit = math.sqrt(3.0 * scale)
# --> 306             return random.uniform(
#     307                 shape, minval=-limit, maxval=limit, dtype=dtype, seed=self.seed
#     308             )
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\random.py in ?(shape, minval, maxval, dtype, seed)
#      31 def uniform(shape, minval=0.0, maxval=1.0, dtype=None, seed=None):
#      32     dtype = dtype or floatx()
#      33     seed = _cast_seed(draw_seed(seed))
# ---> 34     return tf.random.stateless_uniform(
#      35         shape=shape,
#      36         minval=tf.cast(minval, dtype),
#      37         maxval=tf.cast(maxval, dtype),
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1261
#    1262       # Fallback dispatch system (dispatch v1):
#    1263       try:
#    1264         return dispatch_target(*args, **kwargs)
# -> 1265       except (TypeError, ValueError):
#    1266         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267         # TypeError, when given unexpected types.  So we need to catch both.
#    1268         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\stateless_random_ops.py in ?(shape, seed, minval, maxval, dtype, name, alg)
#     402         key, counter, alg = random_ops_util.get_key_counter_alg(seed, alg)
#     403         rnd = gen_stateless_random_ops_v2.stateless_random_uniform_v2(
#     404             shape, key=key, counter=counter, dtype=dtype, alg=alg
#     405         )
# --> 406         result = math_ops.add(rnd * (maxval - minval), minval, name=name)
#     407     shape_util.maybe_set_static_shape(result, shape)
#     408     return result
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\framework\override_binary_operator.py in ?(x, y)
#     110         # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111         #   r_binary_op_wrapper use different force_same_dtype values.
#     112         x, y = maybe_promote_tensors(x, y)
#     113         return func(x, y, name=name)
# --> 114       except (TypeError, ValueError) as e:
#     115         # Even if dispatching the op failed, the RHS may be a tensor aware
#     116         # object that can implement the operator with knowledge of itself
#     117         # and the tensor.
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\tensor_math_operator_overrides.py in ?(x, y, name)
#      72             name=name,
#      73         ),
#      74         dtypes.bool,
#      75     )  # pylint: disable=protected-access
# ---> 76   return math_ops._mul_dispatch(x, y, name=name)  # pylint: disable=protected-access
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#    1745     new_vals = gen_sparse_ops.sparse_dense_cwise_mul(y.indices, y.values,
#    1746                                                      y.dense_shape, x, name)
#    1747     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1748   else:
# -> 1749     return multiply(x, y, name=name)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\weak_tensor_ops.py in ?(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#     145     bound_kwargs = bound_arguments.arguments
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1261
#    1262       # Fallback dispatch system (dispatch v1):
#    1263       try:
#    1264         return dispatch_target(*args, **kwargs)
# -> 1265       except (TypeError, ValueError):
#    1266         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267         # TypeError, when given unexpected types.  So we need to catch both.
#    1268         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#     522
#     523    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     524   """
#     525
# --> 526   return gen_math_ops.mul(x, y, name)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, name)
#    6825         _ctx, "Mul", name, x, y)
#    6826       return _result
#    6827     except _core._NotOkStatusException as e:
#    6828       _ops.raise_from_not_ok_status(e, name)
# -> 6829     except _core._FallbackException:
#    6830       pass
#    6831     try:
#    6832       return mul_eager_fallback(
#
# KeyboardInterrupt:

# %%
img=image.load_img(r"C:\Users\HP\Desktop\SI-GuidedProject-322160-1664774275-main\Dataset\test\leukonychia\19.PNG",target_size=(64,64))

# %%
x=image.img_to_array(img)

# %%
img = image.img_to_array(img)
img = preprocess_input(img)
img = img / 255.0

# ADD THIS LINE
img = np.expand_dims(img, axis=0)

# %%
pred = model.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step

# %%
model.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# array([[0.05991578, 0.0704023 , 0.04854706, 0.02121834, 0.1669237 ,
#         0.02207481, 0.03820575, 0.03241831, 0.10945606, 0.07762614,
#         0.10032951, 0.01425071, 0.03005855, 0.07544203, 0.07294168,
#         0.04934767, 0.01084164]], dtype=float32)

# %%
output=np.argmax(model.predict(img), axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step

# %%
index=['Darier_s disease', 'Muehrck-e_s lines','aloperia areata','beau_s lines','bulish nail',
      'clubbing','eczema','half and half nails(Lindsay_s nails)','koilonychia','leukonychia',
      'onycholycis','pale nail','red lumula','splinter hemnorrage','terry_s nail','white nail','yello nails']
result = str(index[output[0]])
result
# Out:
# 'bulish nail'
